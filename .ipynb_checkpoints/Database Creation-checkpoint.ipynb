# %%
import pandas as pd
import sqlite3

# %% [markdown]
# # Player Data

# %%
df1 = pd.read_csv('player_defense.csv')
df2 = pd.read_csv('player_gsc.csv')
df3 = pd.read_csv('player_misc.csv')
df4 = pd.read_csv('player_passing.csv')
df5 = pd.read_csv('player_possesion.csv')
df6 = pd.read_csv('player_shooting.csv')
df7 = pd.read_csv('player_time.csv')

# %%
players = df1[['Player', 'Nation', 'Pos', 'Squad', 'Age', 'Born', '90s']]
#create ID column
players.reset_index(inplace = True)
players['index'] = list(map(lambda x: x+1, players['index']))
players.rename(columns = {'index':'Id'}, inplace = True)
players['Nation'] = list(map(lambda x: x[-3:], players['Nation']))
players['Age'] = list(map(lambda x: x[:2], players['Age']))

defense = df1.drop(['Rk', 'Nation', 'Pos', 'Squad', 'Age', 'Born', '90s', 'Matches', '-9999', 'Tkl%', '%', 'Tkl+Int'], 1)
gsc = df2.drop(['Rk', 'Nation', 'Pos', 'Squad', 'Age', 'Born', '90s', 'Matches', '-9999', 'SCA', 'SCA90', 'GCA', 'GCA90'], 1)
misc = df3.drop(['Rk', 'Nation', 'Pos', 'Squad', 'Age', 'Born', '90s', 'Matches', '-9999', 'Int', 'TklW'],1)
passing = df4.drop(['Rk', 'Nation', 'Pos', 'Squad', 'Age', 'Born', '90s', 'Matches', '-9999', 'Cmp.1', 'Att.1', 'Cmp%.1', 'Cmp%.2', 'Cmp%.3', 'A-xA', 'KP', '1/3'], 1)
possession = df5.drop(['Rk', 'Nation', 'Pos', 'Squad', 'Age', 'Born', '90s', 'Matches', '-9999', 'Touches', 'Live', 'Succ%', '1/3'], 1)
shooting = df6.drop(['Rk', 'Nation', 'Pos', 'Squad', 'Age', 'Born', '90s', 'SoT%', 'Sh/90', 'SoT/90', 'G/Sh', 'G/SoT', 'npxG/Sh', 'G-xG', 'np:G-xG'], 1)
playtime = df7.drop(['Rk', 'Nation', 'Pos', 'Squad', 'Age', 'Born', '90s', 'Matches', '-9999', 'Mn/MP', 'Min%', '+/-', '+/-90', 'xG+/-', 'xG+/-90', 'On-Off.1'], 1)
# Out:
# C:\Users\Brian\AppData\Local\Temp/ipykernel_30868/3557681887.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   players['index'] = list(map(lambda x: x+1, players['index']))
# C:\Users\Brian\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# C:\Users\Brian\AppData\Local\Temp/ipykernel_30868/3557681887.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   players['Nation'] = list(map(lambda x: x[-3:], players['Nation']))
# C:\Users\Brian\AppData\Local\Temp/ipykernel_30868/3557681887.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   players['Age'] = list(map(lambda x: x[:2], players['Age']))
# C:\Users\Brian\AppData\Local\Temp/ipykernel_30868/3557681887.py:9: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   defense = df1.drop(['Rk', 'Nation', 'Pos', 'Squad', 'Age', 'Born', '90s', 'Matches', '-9999', 'Tkl%', '%', 'Tkl+Int'], 1)
# C:\Users\Brian\AppData\Local\Temp/ipykernel_30868/3557681887.py:10: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   gsc = df2.drop(['Rk', 'Nation', 'Pos', 'Squad', 'Age', 'Born', '90s', 'Matches', '-9999', 'SCA', 'SCA90', 'GCA', 'GCA90'], 1)
# C:\Users\Brian\AppData\Local\Temp/ipykernel_30868/3557681887.py:11: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   misc = df3.drop(['Rk', 'Nation', 'Pos', 'Squad', 'Age', 'Born', '90s', 'Matches', '-9999', 'Int', 'TklW'],1)
# C:\Users\Brian\AppData\Local\Temp/ipykernel_30868/3557681887.py:12: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   passing = df4.drop(['Rk', 'Nation', 'Pos', 'Squad', 'Age', 'Born', '90s', 'Matches', '-9999', 'Cmp.1', 'Att.1', 'Cmp%.1', 'Cmp%.2', 'Cmp%.3', 'A-xA', 'KP', '1/3'], 1)
# C:\Users\Brian\AppData\Local\Temp/ipykernel_30868/3557681887.py:13: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   possession = df5.drop(['Rk', 'Nation', 'Pos', 'Squad', 'Age', 'Born', '90s', 'Matches', '-9999', 'Touches', 'Live', 'Succ%', '1/3'], 1)
# C:\Users\Brian\AppData\Local\Temp/ipykernel_30868/3557681887.py:14: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   shooting = df6.drop(['Rk', 'Nation', 'Pos', 'Squad', 'Age', 'Born', '90s', 'SoT%', 'Sh/90', 'SoT/90', 'G/Sh', 'G/SoT', 'npxG/Sh', 'G-xG', 'np:G-xG'], 1)
# C:\Users\Brian\AppData\Local\Temp/ipykernel_30868/3557681887.py:15: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   playtime = df7.drop(['Rk', 'Nation', 'Pos', 'Squad', 'Age', 'Born', '90s', 'Matches', '-9999', 'Mn/MP', 'Min%', '+/-', '+/-90', 'xG+/-', 'xG+/-90', 'On-Off.1'], 1)

# %%
#add player id to each df
ids = players[['Id', 'Player']]
defense = pd.merge(ids, defense, how = 'inner', on='Player').drop(['Player'], 1)
gsc = pd.merge(ids, gsc, how = 'inner', on='Player').drop(['Player'], 1)
misc = pd.merge(ids, misc, how = 'inner', on='Player').drop(['Player'], 1)
passing = pd.merge(ids, passing, how = 'inner', on='Player').drop(['Player'], 1)
possession = pd.merge(ids, possession, how = 'inner', on='Player').drop(['Player'], 1)
shooting = pd.merge(ids, shooting, how = 'inner', on='Player').drop(['Player'], 1)
playtime = pd.merge(ids, playtime, how = 'inner', on='Player').drop(['Player'], 1)
# Out:
# C:\Users\Brian\AppData\Local\Temp/ipykernel_30868/544113327.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   defense = pd.merge(ids, defense, how = 'inner', on='Player').drop(['Player'], 1)
# C:\Users\Brian\AppData\Local\Temp/ipykernel_30868/544113327.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   gsc = pd.merge(ids, gsc, how = 'inner', on='Player').drop(['Player'], 1)
# C:\Users\Brian\AppData\Local\Temp/ipykernel_30868/544113327.py:5: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   misc = pd.merge(ids, misc, how = 'inner', on='Player').drop(['Player'], 1)
# C:\Users\Brian\AppData\Local\Temp/ipykernel_30868/544113327.py:6: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   passing = pd.merge(ids, passing, how = 'inner', on='Player').drop(['Player'], 1)
# C:\Users\Brian\AppData\Local\Temp/ipykernel_30868/544113327.py:7: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   possession = pd.merge(ids, possession, how = 'inner', on='Player').drop(['Player'], 1)
# C:\Users\Brian\AppData\Local\Temp/ipykernel_30868/544113327.py:8: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   shooting = pd.merge(ids, shooting, how = 'inner', on='Player').drop(['Player'], 1)
# C:\Users\Brian\AppData\Local\Temp/ipykernel_30868/544113327.py:9: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   playtime = pd.merge(ids, playtime, how = 'inner', on='Player').drop(['Player'], 1)

# %%
#connect to mlsdb and create/update players table
with sqlite3.connect('mlsdb.sqlite') as conn:
    c = conn.cursor()
    c.execute('CREATE TABLE IF NOT EXISTS players (id INT, name TEXT, nation TEXT, position TEXT, squad TEXT, age INT, born INT, games REAL)')
    conn.commit()
    players.to_sql('players', conn, if_exists='replace', index = False)
    
    c.execute('CREATE TABLE IF NOT EXISTS playerDefense (playerId INT, tkl REAL, tklW INT, tklDefThird REAL, tklMidThird REAL, tklAttThird REAL, tklVsDrib INT, tklAttVsDrib INT, past INT, press INT, pressW INT, pressDefThird INT, pressMidThird INT, pressAttThird INT, blk INT, blkSh INT, blkSot INT, blkPass INT, int INT, clr INT, err INT)')     
    conn.commit()
    defense.to_sql('stats', conn, if_exists='replace', index = False) 
    
    #check to make sure column names aren't duplicated in the browser
    c.execute('CREATE TABLE IF NOT EXISTS playerGsc(scaPassLive INT, scaPassDead INT, scaDrib INT, scaSh INT, scaFld INT, scaDef INT, gcaPassLive INT, gcaPassDead INT, gcaDrib INT, gcaSh INT, gcaFld INT, gcaDef INT)')
    conn.commit()
    gsc.to_sql('playerGsc', conn, if_exists='replace', index = False)
    
    c.execute('CREATE TABLE IF NOT EXISTS playerMisc(crdY INT, crdR INT, crdR2 INT, fls INT, fld INT, off Int, crs INT, pkWon INT, pkCon INT, og INT, recov INT, airWon INT, airLost INT)')
    conn.commit()
    misc.to_sql('playerMisc', conn, if_exists='replace', index = False)  
    
    c.execute('CREATE TABLE IF NOT EXISTS playerPassing(totDist INT, prgDist INT, shortCmp INT, shortAtt INT, medCmp INT, medAtt INT, lngCmp INT, lngAtt INT, ast INT, xA REAL, passPpa INT, crsPpa INT, progPasses INT)')
    conn.commit()
    passing.to_sql('playerPassing', conn, if_exists='replace', index = False)
    
    c.execute('CREATE TABLE IF NOT EXISTS playerPossession( defPen INT, defThird INT, midThird INT, attThird INT, attPen INT, succDrib INT, attDrib INT, playersBeat INT, megs INT, carries INT, totDist INT, prgDist INT, mishandles INT, tackled INT, passTarg INT, passRec INT, progPassesRec INT)')
    conn.commit()
    possession.to_sql('playerPossession', conn, if_exists='replace', index = False)
    
    c.execute('CREATE TABLE IF NOT EXISTS playerShooting(gls INT, sh INT, sot INT, avgDist REAL, fk INT, succPk INT, pkAtt INT, xG REAL, npxG REAL)')
    conn.commit()
    shooting.to_sql('playerShooting', conn, if_exists='replace', index = False)    
    
    c.execute('CREATE TABLE IF NOT EXISTS playerTime(min INT, starts INT, minPerStart INT, complete INT, subbed INT, minPerSub INT, unSub INT, ppm REAL, onG INT, onGA INT, onOff REAL, onxG REAL, onxGa REAL)')
    conn.commit()
    playtime.to_sql('playerTime', conn, if_exists='replace', index = False)
# Out:
# C:\Users\Brian\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py:2872: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   sql.to_sql(

# %% [markdown]
# # Squad Data

# %%
eastdf = pd.read_csv('squad/eastern_conf.csv')
westdf = pd.read_csv('squad/western_conf.csv')
df1 = pd.concat([eastdf, westdf])
df1.replace('CF MontrÃ©al', 'CF Montréal', inplace = True)
df2 = pd.read_csv('squad/passing.csv')
df2.replace('CF MontrÃ©al', 'CF Montréal', inplace = True)
df3 = pd.read_csv('squad/gsc.csv')
df3.replace('CF MontrÃ©al', 'CF Montréal', inplace = True)
df4 = pd.read_csv('squad/shooting.csv')
df4.replace('CF MontrÃ©al', 'CF Montréal', inplace = True)
df5 = pd.read_csv('squad/defense.csv')
df5.replace('CF MontrÃ©al', 'CF Montréal', inplace = True)
df6= pd.read_csv('squad/posession.csv')
df6.replace('CF MontrÃ©al', 'CF Montréal', inplace = True)
df7= pd.read_csv('squad/goalkeeping.csv')
df7.replace('CF MontrÃ©al', 'CF Montréal', inplace = True)
df8 = pd.read_csv('squad/misc.csv')
df8.replace('CF MontrÃ©al', 'CF Montréal', inplace = True)

# %%
squads = df1.drop(['Rk', 'MP', 'GD', 'Pts', 'Pts/MP', 'xGD/90', 'Top Team Scorer', 'Goalkeeper', 'Notes'], 1)
passing = df2.drop(['90s', 'Cmp', 'Att', 'Cmp%', 'Cmp%.1', 'Cmp%.2', 'Cmp%.3', 'A-xA', 'KP'], 1)
gsc = df3.drop(['# Pl', '90s', 'SCA90', 'GCA90'], 1)
shooting = df4.drop(['# Pl', '90s', 'Gls', 'SoT%', 'Sh/90', 'SoT/90', 'G/Sh', 'G/SoT', 'xG', 'npxG', 'npxG/Sh', 'G-xG', 'np:G-xG'], 1)
defense = df5.drop(['# Pl', '90s', 'Tkl%', '%', 'Tkl+Int'], 1)
possession = df6.drop(['# Pl', '90s', 'Touches', 'Succ%', 'Rec%'], 1)
goalkeeping = df7.drop(['# Pl', 'MP', 'Starts', 'Min', '90s', 'GA90', 'Save%', 'W', 'D', 'L', 'CS%', 'Save%', 'PKatt', 'Save%'], 1)
misc = df8.drop(['# Pl', '90s', 'Won%'], 1)
# Out:
# C:\Users\Brian\AppData\Local\Temp/ipykernel_30868/4107269376.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   squads = df1.drop(['Rk', 'MP', 'GD', 'Pts', 'Pts/MP', 'xGD/90', 'Top Team Scorer', 'Goalkeeper', 'Notes'], 1)
# C:\Users\Brian\AppData\Local\Temp/ipykernel_30868/4107269376.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   passing = df2.drop(['90s', 'Cmp', 'Att', 'Cmp%', 'Cmp%.1', 'Cmp%.2', 'Cmp%.3', 'A-xA', 'KP'], 1)
# C:\Users\Brian\AppData\Local\Temp/ipykernel_30868/4107269376.py:3: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   gsc = df3.drop(['# Pl', '90s', 'SCA90', 'GCA90'], 1)
# C:\Users\Brian\AppData\Local\Temp/ipykernel_30868/4107269376.py:4: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   shooting = df4.drop(['# Pl', '90s', 'Gls', 'SoT%', 'Sh/90', 'SoT/90', 'G/Sh', 'G/SoT', 'xG', 'npxG', 'npxG/Sh', 'G-xG', 'np:G-xG'], 1)
# C:\Users\Brian\AppData\Local\Temp/ipykernel_30868/4107269376.py:5: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   defense = df5.drop(['# Pl', '90s', 'Tkl%', '%', 'Tkl+Int'], 1)
# C:\Users\Brian\AppData\Local\Temp/ipykernel_30868/4107269376.py:6: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   possession = df6.drop(['# Pl', '90s', 'Touches', 'Succ%', 'Rec%'], 1)
# C:\Users\Brian\AppData\Local\Temp/ipykernel_30868/4107269376.py:7: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   goalkeeping = df7.drop(['# Pl', 'MP', 'Starts', 'Min', '90s', 'GA90', 'Save%', 'W', 'D', 'L', 'CS%', 'Save%', 'PKatt', 'Save%'], 1)
# C:\Users\Brian\AppData\Local\Temp/ipykernel_30868/4107269376.py:8: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   misc = df8.drop(['# Pl', '90s', 'Won%'], 1)

# %%
squads = squads.reset_index().drop('index', 1).reset_index()
squads['index'] = list(map(lambda x: x+1, squads['index']))
squads.rename(columns = {'index':'Id'}, inplace = True)
squads
ids = squads[['Id', 'Squad']]

passing = pd.merge(ids, passing, how = 'inner', on='Squad').drop(['Squad'], 1)
gsc = pd.merge(ids, gsc, how = 'inner', on='Squad').drop(['Squad'], 1)
shooting = pd.merge(ids, shooting, how = 'inner', on='Squad').drop(['Squad'], 1)
defense = pd.merge(ids, defense, how = 'inner', on='Squad').drop(['Squad'], 1)
possession = pd.merge(ids, possession, how = 'inner', on='Squad').drop(['Squad'], 1)
goalkeeping = pd.merge(ids, goalkeeping, how = 'inner', on='Squad').drop(['Squad'], 1)
misc = pd.merge(ids, misc, how = 'inner', on='Squad').drop(['Squad'], 1)
# Out:
# C:\Users\Brian\AppData\Local\Temp/ipykernel_30868/2217414956.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   squads = squads.reset_index().drop('index', 1).reset_index()
# C:\Users\Brian\AppData\Local\Temp/ipykernel_30868/2217414956.py:7: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   passing = pd.merge(ids, passing, how = 'inner', on='Squad').drop(['Squad'], 1)
# C:\Users\Brian\AppData\Local\Temp/ipykernel_30868/2217414956.py:8: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   gsc = pd.merge(ids, gsc, how = 'inner', on='Squad').drop(['Squad'], 1)
# C:\Users\Brian\AppData\Local\Temp/ipykernel_30868/2217414956.py:9: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   shooting = pd.merge(ids, shooting, how = 'inner', on='Squad').drop(['Squad'], 1)
# C:\Users\Brian\AppData\Local\Temp/ipykernel_30868/2217414956.py:10: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   defense = pd.merge(ids, defense, how = 'inner', on='Squad').drop(['Squad'], 1)
# C:\Users\Brian\AppData\Local\Temp/ipykernel_30868/2217414956.py:11: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   possession = pd.merge(ids, possession, how = 'inner', on='Squad').drop(['Squad'], 1)
# C:\Users\Brian\AppData\Local\Temp/ipykernel_30868/2217414956.py:12: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   goalkeeping = pd.merge(ids, goalkeeping, how = 'inner', on='Squad').drop(['Squad'], 1)
# C:\Users\Brian\AppData\Local\Temp/ipykernel_30868/2217414956.py:13: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   misc = pd.merge(ids, misc, how = 'inner', on='Squad').drop(['Squad'], 1)

# %%
with sqlite3.connect('mlsdb.sqlite') as conn:
    c = conn.cursor()
    c.execute('CREATE TABLE IF NOT EXISTS squads (id INT, squad TEXT, w INT, d INT, l INT, gf INT, ga INT, xG REAL, xGA REAL, last5 TEXT, attendence INT)')
    conn.commit()
    squads.to_sql('squads', conn, if_exists='replace', index = False)
    
    c.execute('CREATE TABLE IF NOT EXISTS squadPassing (squadId INT, totDist INT, prgDist INT, shortCmp INT, shortAtt INT, medCmp INT, medAtt INT, lngCmp INT, lngAtt INT, ast INT, xA INT, attThird INT, ppa INT, crsPa INT, prog INT)')
    conn.commit()
    passing.to_sql('squadPassing', conn, if_exists='replace', index = False)  
    
    c.execute('CREATE TABLE IF NOT EXISTS squadGsc (squadId INT, scPassLive INT, scPassDead INT, scDrib INT, scSh INT, scFld INT, scDef INT, gcPassLive INT, gcPassDead INT, gcDrib INT, gcSh INT, gcFld INT, gcDef INT)')
    conn.commit()
    gsc.to_sql('squadGsc', conn, if_exists='replace', index = False) 
    
    c.execute('CREATE TABLE IF NOT EXISTS squadShooting (squadId INT, sh INT, sot INT, distance REAL, fk INT, pk INT, pkAtt INT)')
    conn.commit()
    shooting.to_sql('squadShooting', conn, if_exists='replace', index = False)
    
    c.execute('CREATE TABLE IF NOT EXISTS squadDefense (squadId INT, tkl INT, tklW INT, tklDef INT, tklMid INT, tklAtt INT, tklVsDrib INT, attVsDrib INT, beaten INT, press INT, pressSucc INT, pressDef INT, pressMid INT, pressAtt INT, blk INT, blkSh INT, blkShSv INT, blkPass INT, int INT, clr INT, err INT)')
    conn.commit()
    defense.to_sql('squadDefense', conn, if_exists='replace', index = False) 
    
    c.execute('CREATE TABLE IF NOT EXISTS squadPossession (squadId INT, touchesDefPen INT, touchesDef INT, touchesMid INT, touchesAtt INT, touchesAttPen INT, touchesLive INT, dribbSucc INT, dribAtt INT, playersBeat INT, megs INT, carries INT, dist INT, prgDist INT, progCarries INT, carriesAtt INT, carriesPA INT, mis INT, dis INT, passTarg INT, passRec INT, progPassRec INT)')
    conn.commit()
    possession.to_sql('squadPossession', conn, if_exists='replace', index = False) 
    
    c.execute('CREATE TABLE IF NOT EXISTS squadGoalkeeping (squadId INT, sotA INT, saves INT, cs INT, pka INT, pksv INT, pkm INT)')
    conn.commit()
    goalkeeping.to_sql('squadGoalkeeping', conn, if_exists='replace', index = False) 
    
    c.execute('CREATE TABLE IF NOT EXISTS squadMisc (squadId INT, crdY INT, crdR INT, crY2 INT, fls INT, fld INT, off INT, crs INT, og INT, recovery INT, airW INT, airL INT)')
    conn.commit()
    misc.to_sql('squadMisc', conn, if_exists='replace', index = False)

# %%
with sqlite3.connect('mlsdb.sqlite') as conn:
    sql_query = pd.read_sql_query('SELECT * FROM squadDefense', conn)
sql_query
# Out:
#     Id  Tkl  TklW  Def 3rd  Mid 3rd  Att 3rd  Tkl.1  Att  Past  Press  ...  \
# 0    1  228   141       98      102       28     81  190   109   2210  ...
# 1    2  429   265      156      203       70    166  410   244   3634  ...
# 2    3  365   207      177      141       47    118  278   160   2988  ...
# 3    4  300   185      157       98       45    110  243   133   2421  ...
# 4    5  297   183      160       86       51    126  269   143   2681  ...
# 5    6  344   212      184      114       46    107  279   172   2816  ...
# 6    7  251   162      120       95       36    120  248   128   2242  ...
# 7    8  308   192      175      100       33    107  276   169   2293  ...
# 8    9  271   171      131      109       31     96  229   133   2205  ...
# 9   10  312   178      145      125       42    126  255   129   2801  ...
# 10  11  274   168      139       94       41    109  233   124   2142  ...
# 11  12  299   188      130      126       43    111  261   150   2806  ...
# 12  13  326   203      152      128       46    104  265   161   2313  ...
# 13  14  233   135      111       92       30     84  226   142   2538  ...
# 14  15  300   188      147       98       55    130  309   179   2728  ...
# 15  16  257   160      126       84       47     79  216   137   2515  ...
# 16  17  284   179      138       99       47    103  252   149   2493  ...
# 17  18  315   184      167      107       41    121  251   130   2586  ...
# 18  19  248   158      124      105       19    102  229   127   2549  ...
# 19  20  234   156      112       84       38     93  232   139   2198  ...
# 20  21  258   152      150       81       27    104  262   158   2211  ...
# 21  22  328   202      202       94       32    112  278   166   2719  ...
# 22  23  263   168      149       85       29     87  245   158   2379  ...
# 23  24  298   182      141      119       38    115  245   130   2730  ...
# 24  25  284   177      168       72       44     88  240   152   2704  ...
# 25  26  257   159      115      112       30    102  230   128   2102  ...
# 26  27  268   168      102      118       48     86  196   110   2562  ...
# 27  28  287   186      138      108       41    110  240   130   2269  ...
#
#     Def 3rd.1  Mid 3rd.1  Att 3rd.1  Blocks  Sh  ShSv  Pass  Int  Clr  Err
# 0         635       1028        547     200  32     2   168  246  255    8
# 1         908       1654       1072     268  43     1   225  319  341    5
# 2         893       1358        737     304  74     1   230  280  394    4
# 3         843       1001        577     240  45     0   195  262  278    3
# 4         878       1190        613     232  58     0   174  229  331    3
# 5         989       1181        646     296  62     2   234  294  339    1
# 6         725        965        552     230  75     0   155  230  330    3
# 7         894        989        410     218  61     1   157  281  350    5
# 8         681       1011        513     205  48     1   157  290  250    4
# 9         862       1279        660     252  63     0   189  282  298    5
# 10        670        923        549     236  63     1   173  260  215    3
# 11        933       1206        667     270  65     0   205  304  321    4
# 12        726       1043        544     234  58     2   176  292  331    3
# 13        726       1188        624     222  48     2   174  257  294    4
# 14        792       1167        769     210  50     1   160  271  268    4
# 15        738       1095        682     218  57     0   161  239  264   11
# 16        742       1136        615     244  45     0   199  267  352    7
# 17        853       1069        664     226  48     3   178  212  306    1
# 18        923       1111        515     243  58     0   185  229  314    7
# 19        674        910        614     204  42     1   162  221  266    2
# 20        787        952        472     202  63     0   139  291  303    5
# 21       1053       1034        632     278  79     0   199  300  395    4
# 22        871        935        573     248  70     1   178  262  365    3
# 23        904       1207        619     278  67     2   211  322  364    3
# 24        986       1098        620     231  70     2   161  293  356    5
# 25        600       1022        480     214  66     2   148  224  278    2
# 26        624       1208        730     238  52     0   186  284  315    2
# 27        675       1041        553     192  47     2   145  273  216    4
#
# [28 rows x 21 columns]

# %%
conn = sqlite3.connect('test_database') 
          
sql_query = pd.read_sql_query ('''
                               SELECT
                               *
                               FROM products
                               ''', conn)

df = pd.DataFrame(sql_query, columns = ['product_id', 'product_name', 'price'])
print (df)
